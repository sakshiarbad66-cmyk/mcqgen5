# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Downloading numpy-2.3.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shree\mcqgen5\env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\shree\mcqgen5\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.1-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 2.1 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.3 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.3 MB 2.1 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.3 MB 2.2 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.3 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.3 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 3.4/11.3 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.3 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.5/11.3 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.3 MB 2.1 MB/s eta 0:00:04
#    ------------------ --------------------- 5.2/11.3 MB 2.0 MB/s eta 0:00:04
#    ------------------- -------------------- 5.5/11.3 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 6.0/11.3 MB 1.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.6/11.3 MB 1.8 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.3 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 7.3/11.3 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 7.9/11.3 MB 1.9 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 1.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.3 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.3 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 9.2/11.3 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.3 MB 1.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.0/11.3 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.3 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 1.7 MB/s eta 0:00:00
# Downloading numpy-2.3.2-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/13.1 MB 2.0 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/13.1 MB 1.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/13.1 MB 2.0 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/13.1 MB 2.0 MB/s eta 0:00:06
#    ------- -------------------------------- 2.4/13.1 MB 2.0 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/13.1 MB 1.7 MB/s eta 0:00:07
#    -------- ------------------------------- 2.9/13.1 MB 1.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.4/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------ --------------------------- 3.9/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------ --------------------------- 3.9/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------ --------------------------- 4.2/13.1 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 4.7/13.1 MB 1.6 MB/s eta 0:00:06
#    --------------- ------------------------ 5.0/13.1 MB 1.6 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.5/13.1 MB 1.6 MB/s eta 0:00:05
#    ------------------ --------------------- 6.0/13.1 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 6.3/13.1 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 6.8/13.1 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.3/13.1 MB 1.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.6/13.1 MB 1.7 MB/s eta 0:00:04
#    ------------------------ --------------- 8.1/13.1 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 8.7/13.1 MB 1.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.2/13.1 MB 1.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.7/13.1 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 10.0/13.1 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 10.5/13.1 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 11.0/13.1 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.3/13.1 MB 1.8 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.1 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 12.1/13.1 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 1.8 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ---------------------------------------- 4/4 [pandas]
#
# Successfully installed numpy-2.3.2 pandas-2.3.1 pytz-2025.2 tzdata-2025.2

# %%
import os 
import json
import pandas as pd
import traceback

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Using cached langchain_core-0.3.72-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Using cached langchain_text_splitters-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Using cached langsmith-0.4.11-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.42-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting requests<3,>=2 (from langchain)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.3-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.1-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Using cached anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.72-py3-none-any.whl (442 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.9-py3-none-any.whl (33 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/2.0 MB 1.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/2.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.3 MB/s eta 0:00:00
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading sqlalchemy-2.0.42-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 1.1 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 1.2 MB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.2 MB/s eta 0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading greenlet-3.2.3-cp311-cp311-win_amd64.whl (297 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached langsmith-0.4.11-py3-none-any.whl (372 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading orjson-3.11.1-cp311-cp311-win_amd64.whl (131 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl (495 kB)
# Using cached anyio-4.10.0-py3-none-any.whl (107 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, urllib3, typing-inspection, tenacity, sniffio, PyYAML, pydantic-core, orjson, jsonpointer, idna, h11, greenlet, charset_normalizer, certifi, annotated-types, SQLAlchemy, requests, pydantic, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langchain-core, langchain-text-splitters, langchain
#
#    - --------------------------------------  1/27 [urllib3]
#    ---- -----------------------------------  3/27 [tenacity]
#    ------- --------------------------------  5/27 [PyYAML]
#    ---------- -----------------------------  7/27 [orjson]
#    ------------- --------------------------  9/27 [idna]
#    ---------------- ----------------------- 11/27 [greenlet]
#    ----------------- ---------------------- 12/27 [charset_normalizer]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ---------------------- ----------------- 15/27 [SQLAlchemy]
#    ----------------------- ---------------- 16/27 [requests]
#    ------------------------- -------------- 17/27 [pydantic]
#    ------------------------- -------------- 17/27 [pydantic]
#    ------------------------- -------------- 17/27 [pydantic]
#    -------------------------- ------------- 18/27 [jsonpatch]
#    ---------------------------- ----------- 19/27 [httpcore]
#    ----------------------------- ---------- 20/27 [anyio]
#    ------------------------------- -------- 21/27 [requests-toolbelt]
#    -------------------------------- ------- 22/27 [httpx]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ----------------------------------- ---- 24/27 [langchain-core]
#    ----------------------------------- ---- 24/27 [langchain-core]
#    ----------------------------------- ---- 24/27 [langchain-core]
#    ----------------------------------- ---- 24/27 [langchain-core]
#    ----------------------------------- ---- 24/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-text-splitters]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    -------------------------------------- - 26/27 [langchain]
#    ---------------------------------------- 27/27 [langchain]
#
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.42 annotated-types-0.7.0 anyio-4.10.0 certifi-2025.8.3 charset_normalizer-3.4.2 greenlet-3.2.3 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-core-0.3.72 langchain-text-splitters-0.3.9 langsmith-0.4.11 orjson-3.11.1 pydantic-2.11.7 pydantic-core-2.33.2 requests-2.32.4 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-inspection-0.4.1 urllib3-2.5.0 zstandard-0.23.0

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (0.3.72)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.12.15-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (0.4.11)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain_community) (2.3.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.7.0-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.6.3-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.3.2-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.20.1-cp311-cp311-win_amd64.whl.metadata (76 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\shree\mcqgen5\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shree\mcqgen5\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shree\mcqgen5\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\shree\mcqgen5\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\shree\mcqgen5\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shree\mcqgen5\env\lib\site-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shree\mcqgen5\env\lib\site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shree\mcqgen5\env\lib\site-packages (from requests<3,>=2->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shree\mcqgen5\env\lib\site-packages (from requests<3,>=2->langchain_community) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\shree\mcqgen5\env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\shree\mcqgen5\env\lib\site-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\shree\mcqgen5\env\lib\site-packages (from langsmith>=0.1.125->langchain_community) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\shree\mcqgen5\env\lib\site-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\shree\mcqgen5\env\lib\site-packages (from langsmith>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\shree\mcqgen5\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\shree\mcqgen5\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\shree\mcqgen5\env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shree\mcqgen5\env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 1.7 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.5 MB 1.7 MB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.5 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.9 MB/s eta 0:00:00
# Downloading aiohttp-3.12.15-cp311-cp311-win_amd64.whl (453 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.6.3-cp311-cp311-win_amd64.whl (45 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.20.1-cp311-cp311-win_amd64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.7.0-cp311-cp311-win_amd64.whl (44 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.3.2-cp311-cp311-win_amd64.whl (41 kB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain_community
#
#    ------- --------------------------------  3/16 [multidict]
#    --------------- ------------------------  6/16 [frozenlist]
#    -------------------- -------------------  8/16 [aiohappyeyeballs]
#    ------------------------------ --------- 12/16 [pydantic-settings]
#    ----------------------------------- ---- 14/16 [aiohttp]
#    ----------------------------------- ---- 14/16 [aiohttp]
#    ----------------------------------- ---- 14/16 [aiohttp]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ---------------------------------------- 16/16 [langchain_community]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 attrs-25.3.0 dataclasses-json-0.6.7 frozenlist-1.7.0 httpx-sse-0.4.1 langchain_community-0.3.27 marshmallow-3.26.1 multidict-6.6.3 mypy-extensions-1.1.0 propcache-0.3.2 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0 yarl-1.20.1

# %%
from langchain.chat_models import ChatOpenAI

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
llm=ChatOpenAI(openai_api_key=KEY,model_name="gpt-3.5-turbo",temperature=0.5)
